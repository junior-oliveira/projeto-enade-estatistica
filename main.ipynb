# %%
from filtro_dados import get_base_completa

# Retorna todas as bases filtradas e concatenadas em um único dataframe
base_completa = get_base_completa()

# Salva a base de dados nos formatos csv e xlsx
print('Salvando CSV...')
base_completa.to_csv('bases_de_dados_filtradas/base_completa.csv')
print('Salvando XLSX...')
base_completa.to_excel('bases_de_dados_filtradas/base_completa.xlsx')

# %%
import pandas as pd
base_de_dados = pd.read_csv('bases_de_dados_filtradas/base_completa.csv', low_memory=False, delimiter=';')
